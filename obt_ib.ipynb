# %%
from src.obt import obt

# %%
ob = obt()

# %%
ob.symbol = 'nifty'

# %%
ob.symbol
# Out:
# 'NIFTY'

# %%
ob.MITR=10

# %%
ob.SSAF=0.95

# %%
ob.NOAD=1

# %%
ob.MONTH=3

# %%
df = ob.db.get_past_n_expiry_dates(6, "FUTIDX")

# %%
expd = df
expd = expd.rename(columns={"EXPIRY_DT": "ED"})
expd = expd.assign(ST=expd.shift(ob.MONTH) + pd.Timedelta("1Day"))
expd = expd.assign(ND=expd["ED"])
expd = expd.dropna().reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-8c7320a3fc5e> in <module>
#       1 expd = df
#       2 expd = expd.rename(columns={"EXPIRY_DT": "ED"})
# ----> 3 expd = expd.assign(ST=expd.shift(ob.MONTH) + pd.Timedelta("1Day"))
#       4 expd = expd.assign(ND=expd["ED"])
#       5 expd = expd.dropna().reset_index(drop=True)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
expd = df
expd = expd.rename(columns={"EXPIRY_DT": "ED"})
expd = expd.assign(ST=expd.shift(ob.MONTH) + pd.Timedelta("1Day"))
expd = expd.assign(ND=expd["ED"])
expd = expd.dropna().reset_index(drop=True)

# %%
ob.MONTH
# Out:
# 1

# %%
ob.MONTH = 3

# %%
ob.MONTH
# Out:
# 1

# %%
ob._MONTH
# Out:
# 3
